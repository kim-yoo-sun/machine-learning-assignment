# %% [markdown]
# # Logistic Regression with non-linear features

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import ticker, cm

# %% [markdown]
# ## load training data

# %%
fname_data_train    = 'assignment_10_data_train.csv'
fname_data_test     = 'assignment_10_data_test.csv'

data_train          = np.genfromtxt(fname_data_train, delimiter=',')
data_test           = np.genfromtxt(fname_data_test, delimiter=',')

number_data_train   = data_train.shape[0]
number_data_test    = data_test.shape[0]

data_train_point    = data_train[:, 0:2]
data_train_point_x  = data_train_point[:, 0]
data_train_point_y  = data_train_point[:, 1]
data_train_label    = data_train[:, 2]

data_test_point     = data_test[:, 0:2]
data_test_point_x   = data_test_point[:, 0]
data_test_point_y   = data_test_point[:, 1]
data_test_label     = data_test[:, 2]

data_train_label_class_0    = (data_train_label == 0)
data_train_label_class_1    = (data_train_label == 1)

data_test_label_class_0     = (data_test_label == 0)
data_test_label_class_1     = (data_test_label == 1)

data_train_point_x_class_0  = data_train_point_x[data_train_label_class_0]
data_train_point_y_class_0  = data_train_point_y[data_train_label_class_0]

data_train_point_x_class_1  = data_train_point_x[data_train_label_class_1]
data_train_point_y_class_1  = data_train_point_y[data_train_label_class_1]

data_test_point_x_class_0   = data_test_point_x[data_test_label_class_0]
data_test_point_y_class_0   = data_test_point_y[data_test_label_class_0]

data_test_point_x_class_1   = data_test_point_x[data_test_label_class_1]
data_test_point_y_class_1   = data_test_point_y[data_test_label_class_1]

print('shape of point in train data = ', data_train_point.shape)
print('shape of point in test data = ', data_train_point.shape)

print('shape of label in train data = ', data_test_label.shape)
print('shape of label in test data = ', data_test_label.shape)

print('data type of point x in train data = ', data_train_point_x.dtype)
print('data type of point y in train data = ', data_train_point_y.dtype)

print('data type of point x in test data = ', data_test_point_x.dtype)
print('data type of point y in test data = ', data_test_point_y.dtype)
# Out:
# shape of point in train data =  (500, 2)
# shape of point in test data =  (500, 2)
# shape of label in train data =  (500,)
# shape of label in test data =  (500,)
# data type of point x in train data =  float64
# data type of point y in train data =  float64
# data type of point x in test data =  float64
# data type of point y in test data =  float64

# %% [markdown]
# ## plot the data

# %%
f = plt.figure(figsize=(8,8))   

plt.title('points in train data')
plt.plot(data_train_point_x_class_0, data_train_point_y_class_0, 'o', color='blue', label='class = 0')
plt.plot(data_train_point_x_class_1, data_train_point_y_class_1, 'o', color='red', label='class = 1')
plt.axis('equal')
plt.legend()
plt.tight_layout()
plt.show()

# %%
f = plt.figure(figsize=(8,8))   

plt.title('points in test data')
plt.plot(data_test_point_x_class_0, data_test_point_y_class_0, 'o', color='blue', label='class = 0')
plt.plot(data_test_point_x_class_1, data_test_point_y_class_1, 'o', color='red', label='class = 1')
plt.axis('equal')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## define the feature functions

# %% [markdown]
# - feature vector is defined by $(1, f_1(x, y), f_2(x, y), \cdots, f_{k-1}(x, y)) \in \mathbb{R}^k$

# %%
def compute_feature(point):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    feature = np.array([np.ones(point[:,0].shape), point[:,0], point[:,1], point[:,0] * point[:,0], point[:,1] * point[:,1], point[:,0] * point[:,1], point[:,0] * point[:,0] * point[:,0], point[:,1] * point[:,1] * point[:,1], point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1], point[:,0] * point[:,1] * point[:,1] * point[:,1] * point[:,1], point[:,0] * point[:,0] * point[:,1] * point[:,1] * point[:,1], point[:,0] * point[:,0] * point[:,0] * point[:,1] * point[:,1],\
                       point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1],\
                       point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1],\
                       point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1],\
                       np.cos(point[:,1]) * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1] * point[:,1]])
    feature = feature.T
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return feature

# %% [markdown]
# ## define the linear regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature = $(1, f_1(x, y), \cdots, f_{k-1}(x, y)) \in \mathbb{R}^k$

# %%
def compute_linear_regression(theta, feature):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    value = np.matmul(theta, feature.T)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return value

# %% [markdown]
# ## define sigmoid function with input

# %% [markdown]
# - $z \in \mathbb{R}$

# %%
def sigmoid(z):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    value = 1 / (1 + np.exp(-z))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the logistic regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$

# %%
def compute_logistic_regression(theta, feature):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    value = sigmoid(compute_linear_regression(theta, feature))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the residual function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_residual(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    label = label.squeeze()
    residual = residual = (- 1) * (label * np.log1p(compute_logistic_regression(theta, feature)) + (np.ones(label.shape[0])-label) * (np.log1p(np.ones(label.shape[0])-compute_logistic_regression(theta, feature))))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return residual

# %% [markdown]
# ## define the loss function for the logistic regression

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_loss(theta, feature, label, alpha):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    label = label.squeeze()
    loss = np.sum(compute_residual(theta, feature, label)) / (label.shape[0]) + (alpha / 2) * np.inner(theta, theta)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return loss

# %% [markdown]
# ## define the gradient of the loss with respect to the model parameter $\theta$

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_gradient(theta, feature, label, alpha):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    label = label.squeeze()
    gradient = (np.matmul(np.multiply(np.ones(label.shape[0]) - label, compute_logistic_regression(theta, feature)), feature) + np.matmul(np.multiply(label, compute_logistic_regression(theta, feature) - np.ones(label.shape[0])), feature)) / label.shape[0] + alpha * theta
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return gradient

# %% [markdown]
# ## compute the accuracy of the prediction for point with a given model parameter

# %%
def compute_accuracy(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    correct_count = 0
    total_count = 0
    value = compute_logistic_regression(theta, feature)
    
    for i in range(label.shape[0]):
        if value[i] >= 0.5:
            total_count = total_count + 1
            if label[i] == 1:
                correct_count = correct_count + 1
        else:
            total_count = total_count + 1
            if label[i] == 0:
                correct_count = correct_count + 1
    
    accuracy = correct_count / total_count
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return accuracy

# %% [markdown]
# ## initialize the gradient descent algorithm

# %%
number_iteration    = 150000 # you can change this value as you want
learning_rate       = 0.3 # you can change this value as you want
number_feature      = 16 # you can change this value as you want
alpha               = 0.000005# 0 빼고 1 넣으면 완벽 # you can change this value as you want

theta                       = np.zeros(number_feature)
loss_iteration_train        = np.zeros(number_iteration)
loss_iteration_test         = np.zeros(number_iteration)
accuracy_iteration_train    = np.zeros(number_iteration)
accuracy_iteration_test     = np.zeros(number_iteration)

# %% [markdown]
# ## run the gradient descent algorithm to optimize the loss function with respect to the model parameter

# %%
for i in range(number_iteration):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    np.seterr(all="ignore") # 연산 overflow 표시 방지, overflow가 나온 경우, 실제 값은 잘 나옴.
 
    theta           = theta - learning_rate * compute_gradient(theta, compute_feature(data_train), data_train[:,2], alpha)
    loss_train      = compute_loss(theta, compute_feature(data_train), data_train[:,2], alpha)
    loss_test       = compute_loss(theta, compute_feature(data_test), data_test[:,2], alpha)
    accuracy_train  = compute_accuracy(theta, compute_feature(data_train), data_train[:,2])
    accuracy_test   = compute_accuracy(theta, compute_feature(data_test), data_test[:,2])

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    loss_iteration_train[i]     = loss_train
    loss_iteration_test[i]      = loss_test
    accuracy_iteration_train[i] = accuracy_train
    accuracy_iteration_test[i]  = accuracy_test

theta_optimal = theta

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
def function_result_01():

    print("final training accuracy = {:13.10f}".format(accuracy_iteration_train[-1]))

# %%
def function_result_02():

    print("final testing accuracy = {:13.10f}".format(accuracy_iteration_test[-1]))

# %%
def function_result_03():
    
    plt.figure(figsize=(8,6))
    plt.title('training loss')

    plt.plot(loss_iteration_train, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def function_result_04():

    plt.figure(figsize=(8,6))
    plt.title('testing loss')

    plt.plot(loss_iteration_test, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6))
    plt.title('training accuracy')

    plt.plot(accuracy_iteration_train, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('accuracy')

    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6))
    plt.title('testing accuracy')

    plt.plot(accuracy_iteration_test, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('accuracy')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## plot the linear regression values over the 2-dimensional Euclidean space and superimpose the training data

# %%
def function_result_07():

    plt.figure(figsize=(8,8)) 
    plt.title('linear regression values on the training data')
    
    min_x   = np.min(data_train_point_x)
    max_x   = np.max(data_train_point_x)
    min_y   = np.min(data_train_point_y)
    max_y   = np.max(data_train_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) 
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) 

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    YY = np.flip(YY)

    plt.title('linear regression values')
    plt.plot(data_train_point_x_class_0, data_train_point_y_class_0, 'o', color='blue', label='class = 0', markersize=3)
    plt.plot(data_train_point_x_class_1, data_train_point_y_class_1, 'o', color='red', label='class = 1', markersize=3)
    # plt.legend(loc='upper right')
    
    ZZ = theta_optimal[0] * (np.ones(XX.shape)) + theta_optimal[1] * (XX) +\
    theta_optimal[2] * (YY) + theta_optimal[3] * (XX * XX) +\
    theta_optimal[4] * (YY * YY) + theta_optimal[5] * (XX * YY)+\
    theta_optimal[6] * (XX * XX * XX) + theta_optimal[7] * (YY * YY * YY)+\
    theta_optimal[8] * (YY * YY * YY * YY * YY) + theta_optimal[9] * (XX * YY * YY * YY * YY)+\
    theta_optimal[10] * (XX * XX * YY * YY * YY) + theta_optimal[11] * (XX * XX * XX * YY * YY)+\
    theta_optimal[12] * (YY * YY * YY * YY * YY * YY) + theta_optimal[13] * (YY * YY * YY * YY * YY * YY * YY)+\
    theta_optimal[14] * (YY * YY * YY * YY * YY * YY * YY * YY) + theta_optimal[15] * (np.cos(YY) * YY * YY * YY * YY * YY * YY * YY * YY)
    extent = min_x, max_x, min_y, max_y
    
    # plt.plot(XX,YY)
    
    plt.contour(XX, YY, ZZ, levels=0, colors='black')
    
    boundary_ = np.arange(-20,25,0.0125*45).tolist()
    plt.contourf(XX, YY, ZZ, cmap=cm.RdBu_r, levels = 75)
    plt.colorbar()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.plot(data_train_point_x_class_0, data_train_point_y_class_0, '.', color='blue', label='class = 0')
    plt.plot(data_train_point_x_class_1, data_train_point_y_class_1, '.', color='red', label='class = 1')

    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,8)) 
    plt.title('linear regression values on the testing data')
    
    min_x   = np.min(data_test_point_x)
    max_x   = np.max(data_test_point_x)
    min_y   = np.min(data_test_point_y)
    max_y   = np.max(data_test_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1)
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) 

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    YY = np.flip(YY)

    plt.title('linear regression values')
    plt.plot(data_test_point_x_class_0, data_test_point_y_class_0, 'o', color='blue', label='class = 0', markersize=3)
    plt.plot(data_test_point_x_class_1, data_test_point_y_class_1, 'o', color='red', label='class = 1', markersize=3)
    # plt.legend(loc='upper right')
    
    ZZ = theta_optimal[0] * (np.ones(XX.shape)) + theta_optimal[1] * (XX) +\
    theta_optimal[2] * (YY) + theta_optimal[3] * (XX * XX) +\
    theta_optimal[4] * (YY * YY) + theta_optimal[5] * (XX * YY)+\
    theta_optimal[6] * (XX * XX * XX) + theta_optimal[7] * (YY * YY * YY)+\
    theta_optimal[8] * (YY * YY * YY * YY * YY) + theta_optimal[9] * (XX * YY * YY * YY * YY)+\
    theta_optimal[10] * (XX * XX * YY * YY * YY) + theta_optimal[11] * (XX * XX * XX * YY * YY)+\
    theta_optimal[12] * (YY * YY * YY * YY * YY * YY) + theta_optimal[13] * (YY * YY * YY * YY * YY * YY * YY)+\
    theta_optimal[14] * (YY * YY * YY * YY * YY * YY * YY * YY) + theta_optimal[15] * (np.cos(YY) * YY * YY * YY * YY * YY * YY * YY * YY)
    extent = min_x, max_x, min_y, max_y
    
    # plt.plot(XX,YY)
    
    plt.contour(XX, YY, ZZ, levels=0, colors='black')
    
    boundary_ = np.arange(-20,25,0.0125*45).tolist()
    plt.contourf(XX, YY, ZZ, cmap=cm.RdBu_r, levels = 75)
    plt.colorbar()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.plot(data_test_point_x_class_0, data_test_point_y_class_0, '.', color='blue', label='class = 0')
    plt.plot(data_test_point_x_class_1, data_test_point_y_class_1, '.', color='red', label='class = 1')

    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## plot the logistic regression values over the 2-dimensional Euclidean space

# %%
def function_result_09():

    plt.figure(figsize=(8,8)) 
    plt.title('logistic regression values on the training data')
    
    min_x   = np.min(data_train_point_x)
    max_x   = np.max(data_train_point_x)
    min_y   = np.min(data_train_point_y)
    max_y   = np.max(data_train_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) 
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) 

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    YY = np.flip(YY)

    plt.title('linear regression values')
    plt.plot(data_train_point_x_class_0, data_train_point_y_class_0, 'o', color='blue', label='class = 0', markersize=3)
    plt.plot(data_train_point_x_class_1, data_train_point_y_class_1, 'o', color='red', label='class = 1', markersize=3)
    # plt.legend(loc='upper right')
    
    ZZ = theta_optimal[0] * (np.ones(XX.shape)) + theta_optimal[1] * (XX) +\
    theta_optimal[2] * (YY) + theta_optimal[3] * (XX * XX) +\
    theta_optimal[4] * (YY * YY) + theta_optimal[5] * (XX * YY)+\
    theta_optimal[6] * (XX * XX * XX) + theta_optimal[7] * (YY * YY * YY)+\
    theta_optimal[8] * (YY * YY * YY * YY * YY) + theta_optimal[9] * (XX * YY * YY * YY * YY)+\
    theta_optimal[10] * (XX * XX * YY * YY * YY) + theta_optimal[11] * (XX * XX * XX * YY * YY)+\
    theta_optimal[12] * (YY * YY * YY * YY * YY * YY) + theta_optimal[13] * (YY * YY * YY * YY * YY * YY * YY)+\
    theta_optimal[14] * (YY * YY * YY * YY * YY * YY * YY * YY) + theta_optimal[15] * (np.cos(YY) * YY * YY * YY * YY * YY * YY * YY * YY)
    extent = min_x, max_x, min_y, max_y
    ZZ = sigmoid(ZZ)
    
    # plt.plot(XX,YY)
    
    # plt.contour(XX, YY, ZZ, levels=0, colors='black')
    
    boundary_ = np.arange(-20,25,0.0125*45).tolist()
    plt.contourf(XX, YY, ZZ, cmap=cm.RdBu_r, levels = 75)
    plt.colorbar()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++


    plt.plot(data_train_point_x_class_0, data_train_point_y_class_0, '.', color='blue', label='class = 0')
    plt.plot(data_train_point_x_class_1, data_train_point_y_class_1, '.', color='red', label='class = 1')

    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def function_result_10():
    
    plt.figure(figsize=(8,8)) 
    plt.title('logistic regression values on the testing data')

    min_x   = np.min(data_test_point_x)
    max_x   = np.max(data_test_point_x)
    min_y   = np.min(data_test_point_y)
    max_y   = np.max(data_test_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) 
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) 

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    YY = np.flip(YY)

    plt.title('linear regression values')
    plt.plot(data_test_point_x_class_0, data_test_point_y_class_0, 'o', color='blue', label='class = 0', markersize=3)
    plt.plot(data_test_point_x_class_1, data_test_point_y_class_1, 'o', color='red', label='class = 1', markersize=3)
    # plt.legend(loc='upper right')
    
    ZZ = theta_optimal[0] * (np.ones(XX.shape)) + theta_optimal[1] * (XX) +\
    theta_optimal[2] * (YY) + theta_optimal[3] * (XX * XX) +\
    theta_optimal[4] * (YY * YY) + theta_optimal[5] * (XX * YY)+\
    theta_optimal[6] * (XX * XX * XX) + theta_optimal[7] * (YY * YY * YY)+\
    theta_optimal[8] * (YY * YY * YY * YY * YY) + theta_optimal[9] * (XX * YY * YY * YY * YY)+\
    theta_optimal[10] * (XX * XX * YY * YY * YY) + theta_optimal[11] * (XX * XX * XX * YY * YY)+\
    theta_optimal[12] * (YY * YY * YY * YY * YY * YY) + theta_optimal[13] * (YY * YY * YY * YY * YY * YY * YY)+\
    theta_optimal[14] * (YY * YY * YY * YY * YY * YY * YY * YY) + theta_optimal[15] * (np.cos(YY) * YY * YY * YY * YY * YY * YY * YY * YY)
    extent = min_x, max_x, min_y, max_y
    ZZ = sigmoid(ZZ)
    
    # plt.plot(XX,YY)
    
    # plt.contour(XX, YY, ZZ, levels=0, colors='black')
    
    boundary_ = np.arange(-20,25,0.0125*45).tolist()
    plt.contourf(XX, YY, ZZ, cmap=cm.RdBu_r, levels = 75)
    plt.colorbar()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++


    plt.plot(data_test_point_x_class_0, data_test_point_y_class_0, '.', color='blue', label='class = 0')
    plt.plot(data_test_point_x_class_1, data_test_point_y_class_1, '.', color='red', label='class = 1')

    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
number_result = 10

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final training accuracy =  0.9200000000
# **************************************************
# ## [RESULT 02]
# **************************************************
# final testing accuracy =  0.9160000000
# **************************************************
# ## [RESULT 03]
# **************************************************
# **************************************************
# ## [RESULT 04]
# **************************************************
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# **************************************************
# ## [RESULT 08]
# **************************************************
# **************************************************
# ## [RESULT 09]
# **************************************************
# **************************************************
# ## [RESULT 10]
# **************************************************
